# %%
import pandas as pd
from sklearn import svm
from sklearn.metrics import roc_curve,auc,classification_report,confusion_matrix
from sklearn.model_selection import KFold,train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# %%
df=pd.read_csv("25%data.csv")
y=df["status_time"]
newdf = pd.DataFrame(scale(df), index=df.index, columns=df.columns)
newdf=newdf.round(3)
df=newdf

# %%
df.drop("id",axis=1,inplace=True)

x=newdf[["LTV_dif","LTV_inc","LTV_time","FICO_orig_time","hpi_inc"]]

# %%
x
# Out:
#        LTV_dif  LTV_inc  LTV_time  FICO_orig_time  hpi_inc
# 0       -0.472   -0.471     0.438           0.807   -0.701
# 1        0.628    0.691    -0.588           0.529    0.584
# 2        1.118    1.209    -1.046          -1.099    1.376
# 3        0.751    0.740    -0.306           0.877    0.654
# 4       -0.049   -0.024     0.043          -0.069   -0.169
# ...        ...      ...       ...             ...      ...
# 10426   -1.419   -1.297     1.718           0.139   -1.067
# 10427   -1.184   -1.223     1.102           1.405   -1.040
# 10428   -0.270   -0.215     0.695          -0.445   -0.509
# 10429   -1.061   -1.312     0.491           0.835   -1.006
# 10430    0.594    0.849    -1.366          -1.043    0.501
#
# [10431 rows x 5 columns]

# %%
df
# Out:
#         time  orig_time  first_time  mat_time  balance_time  LTV_time  \
# 0      2.159      0.939       4.389     0.604        -0.445     0.438
# 1     -0.844     -0.281      -0.554     0.006        -0.550    -0.588
# 2     -1.619     -2.314      -3.179    -1.131        -0.954    -1.046
# 3     -0.941     -0.416      -0.399     0.006        -0.776    -0.306
# 4     -0.263      0.804       0.836     0.485        -0.291     0.043
# ...      ...        ...         ...       ...           ...       ...
# 10426  0.609      0.668       0.991     0.485        -0.846     1.718
# 10427  0.609      0.533       0.527     0.425        -0.248     1.102
# 10428  2.644      0.262       0.219     0.305        -0.681     0.695
# 10429  0.997      0.533       0.064     0.245         0.842     0.491
# 10430 -0.263     -0.281      -0.863    -1.730        -0.500    -1.366
#
#        interest_rate_time  hpi_time  gdp_time  uer_time  ...  gdp_dif  \
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10426    0
# 10427    0
# 10428    0
# 10429    0
# 10430    0
# Name: status_time, Length: 10431, dtype: int64

# %%
kf=KFold(n_splits=5,random_state=2,shuffle=True)

# %%
train_x, test_x, train_y, test_y=train_test_split(x, y, train_size=0.3)

# %%
model = svm.SVC(kernel='poly',gamma=5,C=2) 
model.fit(train_x, train_y)
# Out:
# SVC(C=2, gamma=5, kernel='poly')

# %%
model.score(test_x, test_y)
# Out:
# 0.7422623938646946

# %%
pred_y = model.predict(test_x)
print(confusion_matrix(test_y, pred_y))
# Out:
# [[1063 1582]
#  [ 300 4357]]

# %%
print(classification_report(test_y, pred_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.40      0.53      2645
#            1       0.73      0.94      0.82      4657
#
#     accuracy                           0.74      7302
#    macro avg       0.76      0.67      0.68      7302
# weighted avg       0.75      0.74      0.72      7302
